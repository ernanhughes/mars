# %%
from sqlalchemy import create_engine, Column, Integer, String, Text, DateTime, Float
from sqlalchemy.orm import declarative_base, sessionmaker
from datetime import datetime
import os
from dotenv import load_dotenv
load_dotenv()

PG_CONN_STR = os.getenv("PG_CONN_STR")

Base = declarative_base()
engine = create_engine(PG_CONN_STR)
SessionLocal = sessionmaker(bind=engine)

class MarsStep(Base):
    __tablename__ = "mars_steps"

    id = Column(Integer, primary_key=True, index=True)
    input_question = Column(Text)
    teacher_question = Column(Text)
    critique = Column(Text)
    final_question = Column(Text)
    final_answer = Column(Text)
    teacher_latency = Column(Float)
    critic_latency = Column(Float)
    student_latency = Column(Float)
    teacher_agent = Column(String)
    critic_agent = Column(String)
    student_agent = Column(String)
    timestamp = Column(DateTime, default=datetime.utcnow)

def init_db():
    Base.metadata.create_all(bind=engine)

# %%
def log_mars_step(input_q, teacher_q, critique, final_q, final_a,
                  t_latency=None, c_latency=None, s_latency=None,
                  t_agent="teacher", c_agent="critic", s_agent="student"):
    session = SessionLocal()
    step = MarsStep(
        input_question=input_q,
        teacher_question=teacher_q,
        critique=critique,
        final_question=final_q,
        final_answer=final_a,
        teacher_latency=t_latency,
        critic_latency=c_latency,
        student_latency=s_latency,
        teacher_agent=t_agent,
        critic_agent=c_agent,
        student_agent=s_agent
    )
    session.add(step)
    session.commit()
    session.close()

# %%
import dspy
from dspy import Signature, InputField, OutputField, Module


lm = dspy.LM('ollama_chat/hf.co/ernanhughes/Fin-R1-Q8_0-GGUF', api_base='http://localhost:11434', api_key='')
dspy.configure(lm=lm)

# Step 1: Define DSPy Signature
class AnalyzeMargins(Signature):
    context = InputField(desc="Relevant financial data")
    question = InputField(desc="User's trading question")
    signal = OutputField(desc="Bullish, Bearish, or Neutral")
    rationale = OutputField(desc="Explanation for the signal")

# %%
from dspy import Signature, InputField, OutputField
from dspy import Module, Predict

class FinancialTrendAnalysis(Signature):
    statements = InputField(desc="Multiple income statements across quarters")
    question = InputField(desc="Question about company performance")
    signal = OutputField(desc="bullish, bearish, or neutral")
    rationale = OutputField(desc="Explanation based on financial trends")


class IncomeStatementAnalyzer(Module):
    def __init__(self):
        super().__init__()
        self.analyze = Predict(FinancialTrendAnalysis)
        

    def forward(self, statements, question):
        return self.analyze(statements=statements, question=question)

# %%
import os
from dotenv import load_dotenv
import pandas as pd
from sqlalchemy import create_engine

from edgar import Company, set_identity
from edgar.xbrl2 import *

class EDGARFetcher:
    def __init__(self, ticker: str, form: str = "10-Q", n: int = 3):
        load_dotenv()

        # Load PG and EDGAR credentials
        self.pg_conn_str = os.getenv("PG_CONN_STR")
        self.identity = os.getenv("IDENTITY")
        self.engine = create_engine(self.pg_conn_str)
        self.ticker = ticker
        self.form = form
        self.n = n

        # Set identity for SEC API
        set_identity(self.identity)

    def fetch_markdown_statements(self):
        filings = Company(self.ticker).latest(form=self.form, n=self.n)

        statements = []
        for filing in filings:
            xbrl = XBRL.from_filing(filing)
            income_statement = xbrl.statements.income_statement()
            df = income_statement.to_dataframe()
            statements.append(self.rich_report_to_text(df))
        return statements

    def rich_report_to_text(self, df: pd.DataFrame) -> str:
        """
        Convert a rich EDGAR report DataFrame to readable plain text for LLMs.
        """
        lines = []
        for _, row in df.iterrows():
            label = row.get("original_label") or row.get("label") or row.get("concept")
            values = [
                f"{col}: {row[col]}" for col in df.columns
                if isinstance(col, str) and col.startswith("20") and pd.notna(row[col])
            ]
            if values:
                lines.append(f"{label}: " + " | ".join(values))
        return "\n".join(lines)


    def save_statements_to_db(self, statement_list, table="filings_markdown"):
        for statement in statement_list:
            df = statement.to_dataframe()
            df = df.T
            df = df.reset_index()
            print(df.head())
            df.to_sql(table, con=self.engine, index=False, if_exists="append")
            print(f"Inserted {len(df)} rows into {table}")

    def run(self):
        statements = self.fetch_markdown_statements()
        # self.save_statements_to_db(statements, table="income_statement")
        markdowns = [statement for statement in statements]
        return markdowns
ticker = "TSLA"
n = 3
fetcher = EDGARFetcher(ticker=ticker, n=n)
statements = fetcher.run()

# %%
# Create a utility function to estimate token count from a list of markdown statements

def estimate_token_count(markdown_list: list[str], chars_per_token: int = 4) -> int:
    """
    Estimate the number of tokens used by a list of markdown-formatted statements.

    Args:
        markdown_list (list[str]): A list of markdown text blocks.
        chars_per_token (int): Average number of characters per token. Default is 4.

    Returns:
        int: Estimated total token count.
    """
    combined_text = "\n\n".join(markdown_list)
    total_chars = len(combined_text)
    estimated_tokens = total_chars // chars_per_token
    return estimated_tokens

estimated = estimate_token_count(statements)
estimated
# Out:
# 2116

# %%
def build_analysis_prompt(ticker: str, markdown_list: list[str]) -> str:
    header = f"You are a financial analysis model. Below are the last {len(markdown_list)} income statements from {ticker}.\n\n"
    instructions = (
        "Analyze the trend in revenue and operating income.\n"
        "Decide if profitability is improving or declining.\n"
        "Then provide a trading signal.\n\n"
        "Respond with:\n"
        "Signal: <Bullish/Bearish/Neutral>\n"
        "Rationale: <short explanation>\n\n"
    )
    body = "\n\n".join(markdown_list)
    return header + instructions + body

prompt = build_analysis_prompt(ticker, statements)
print(prompt[:300])
# Out:
# You are a financial analysis model. Below are the last 3 income statements from TSLA.
#
# Analyze the trend in revenue and operating income.
# Decide if profitability is improving or declining.
# Then provide a trading signal.
#
# Respond with:
# Signal: <Bullish/Bearish/Neutral>
# Rationale: <short explanation>

# %%
import litellm
litellm._turn_on_debug()
import logging
logging.basicConfig(level=logging.DEBUG, 
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', 
                    handlers=[logging.FileHandler('vector_db.log', 'w', 'utf-8')])

# %%
from dspy import Signature, InputField, OutputField, Module

from dspy import Module, Predict, ChainOfThought
from dspy import Signature, InputField, OutputField

class TeacherQuestion(Signature):
    prompt = InputField()
    question = OutputField(desc="A Socratic question to improve the prompt")

class TeacherQuestioner(Module):
    def __init__(self, use_chain_of_thought: bool = True):
        super().__init__()
        self.use_chain_of_thought = use_chain_of_thought

        self.generate = (
            ChainOfThought(TeacherQuestion)
            if self.use_chain_of_thought
            else Predict(TeacherQuestion)
        )

    def forward(self, prompt):
        return self.generate(prompt=prompt)


class CritiqueQuestion(Signature):
    question = InputField()
    critique = OutputField(desc="Is the question Socratic? Why or why not?")

class CriticJudge(Module):
    def __init__(self):
        super().__init__()
        self.evaluate = dspy.Predict(CritiqueQuestion)

    def forward(self, question):
        return self.evaluate(question=question)

class MarginAnalyzer(Module):
    def __init__(self):
        super().__init__()
        self.analyze = dspy.ChainOfThought(AnalyzeMargins)

    def forward(self, context, question, teacher_question=None):
        if teacher_question:
            question = f"{question} Consider also: {teacher_question}"
        return self.analyze(context=context, question=question)

# %%
import dspy

class MarsAnalysisProgram(dspy.Program):
    def __init__(self, teacher: dspy.Module, critic: dspy.Module, student: dspy.Module):
        super().__init__()
        self.teacher = teacher
        self.critic = critic
        self.student = student

    def forward(self, context: str, base_question: str):
        # Step 1: Generate Socratic question
        teacher_out = self.teacher(prompt=context + "\n\n" + base_question)
        
        # Step 2: Evaluate Socratic quality
        critic_out = self.critic(question=teacher_out.question)

        # Step 3: Decide final question
        if "yes" in critic_out.critique.lower():
            final_question = f"{base_question} Consider also: {teacher_out.question}"
        else:
            final_question = base_question

        # Step 4: Get Student’s answer
        student_out = self.student(context=context, question=final_question)

        return {
            "teacher_question": teacher_out.question,
            "critique": critic_out.critique,
            "final_question": final_question,
            "signal": student_out.signal,
            "rationale": student_out.rationale
        }

# %%
def log_mars_step(input_q, teacher_q, critique, final_q, final_a,
                  t_latency=None, c_latency=None, s_latency=None,
                  t_agent="teacher", c_agent="critic", s_agent="student",
                  trace_json=None):
    # from db import SessionLocal, MarsStep

    session = SessionLocal()
    step = MarsStep(
        input_question=input_q,
        teacher_question=teacher_q,
        critique=critique,
        final_question=final_q,
        final_answer=final_a,
        teacher_latency=t_latency,
        critic_latency=c_latency,
        student_latency=s_latency,
        teacher_agent=t_agent,
        critic_agent=c_agent,
        student_agent=s_agent,
        trace=trace_json  # ➕ this assumes you added a 'trace' TEXT/JSON column to your table
    )
    session.add(step)
    session.commit()
    session.close()

# %%
teacher = TeacherQuestioner()
critic = CriticJudge()
student = MarginAnalyzer()

program = MarsAnalysisProgram(teacher, critic, student)

results = program(
    context=prompt,
    base_question="Is the company improving its profitability?"
)

dspy.inspect_history()
results
# Out:
# [2025-03-25T10:24:21.892041]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): Relevant financial data
# 2. `question` (str): User's trading question
#
# Your output fields are:
# 1. `signal` (str): Bullish, Bearish, or Neutral
# 2. `rationale` (str): Explanation for the signal
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## signal ## ]]
# {signal}
#
# [[ ## rationale ## ]]
# {rationale}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Given the fields `context`, `question`, produce the fields `signal`, `rationale`.
#
#
# User message:
#
# [[ ## context ## ]]
# You are a financial analysis model. Below are the last 3 income statements from TSLA.
#
# Analyze the trend in revenue and operating income.
# Decide if profitability is improving or declining.
# Then provide a trading signal.
#
# Respond with:
# Signal: <Bullish/Bearish/Neutral>
# Rationale: <short explanation>
#
# Revenues: 2023-01-01_2023-09-30: 71606000000.0 | 2023-07-01_2023-09-30: 23350000000.0 | 2024-01-01_2024-09-30: 71983000000.0 | 2024-07-01_2024-09-30: 25182000000.0
# Income before income taxes: 2023-01-01_2023-03-31: 2800000000.0 | 2024-01-01_2024-03-31: 1553000000.0
# (Benefit from) provision for income taxes: 2023-01-01_2023-03-31: -261000000.0 | 2024-01-01_2024-03-31: -409000000.0
# Net income: 2023-01-01_2023-03-31: 2539000000.0 | 2024-01-01_2024-03-31: 1144000000.0
# nan: 2023-01-01_2023-03-31: -26000000.0 | 2024-01-01_2024-03-31: -15000000.0
# Net income attributable to common stockholders: 2023-01-01_2023-03-31: 2513000000.0 | 2024-01-01_2024-03-31: 1129000000.0
# Basic (in dollars per share): 2023-01-01_2023-03-31: 0.8 | 2024-01-01_2024-03-31: 0.37
# Diluted (in dollars per share): 2023-01-01_2023-03-31: 0.73 | 2024-01-01_2024-03-31: 0.34
# Basic (in shares): 2023-01-01_2023-03-31: 3166000000.0 | 2024-01-01_2024-03-31: 3186000000.0
# Diluted (in shares): 2023-01-01_2023-03-31: 3468000000.0 | 2024-01-01_2024-03-31: 3484000000.0
#
# [[ ## question ## ]]
# Is the company improving its profitability?
#
# Respond with the corresponding output fields, starting with the field `[[ ## signal ## ]]`, then `[[ ## rationale ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## signal ## ]]
# To determine if the company is improving its profitability, we need to analyze key financial metrics such as net income, earnings per share (EPS), and changes in expenses over time. Here's a step-by-step breakdown:
#
# 1. **Net Income Comparison**: Compare net income from 2023 Q1 to 2024 Q1.
#    - 2023 Q1 Net Income: $2,539 million
#    - 2024 Q1 Net Income: $1,144 million
#    - **Change**: A decrease of $1,395 million (from +$2.5B to -$1.14B). This is a significant decline, indicating potential profitability issues.
#
# 2. **Earnings Per Share (EPS)**:
#    - Basic EPS 2023 Q1: $0.80
#    - Diluted EPS 2023 Q1: $0.73
#    - Basic EPS 2024 Q1: $0.37
#    - Diluted EPS 2024 Q1: $0.34
#    - **Basic EPS Change**: Decrease from $0.80 to $0.37 (−$0.43)
#    - **Diluted EPS Change**: Decrease from $0.73 to $0.34 (−$0.39)
#    - Both metrics show a decline, suggesting reduced profitability per share.
#
# 3. **Expense Analysis**:
#    - Interest Expense 2023 Q1: -$29 million
#    - Interest Expense 2024 Q1: -$76 million
#    - Increase in interest expense by $47 million (from −$29M to −$76M), which could be a factor in lower net income.
#    - Provision for Income Taxes 2023 Q1: -$261 million
#    - Provision for Income Taxes 2024 Q1: -$409 million
#    - Increase in tax provisions by $148 million (from −$261M to −$409M), further reducing net income.
#
# 4. **Net Income Attributable to Common Stockholders**:
#    - 2023 Q1: $2,513 million
#    - 2024 Q1: $1,129 million
#    - Decrease of $1,384 million (from +$2.5B to −$1.13B), reinforcing the profitability decline.
#
# **Conclusion**: The company’s net income and EPS have significantly declined from 2023 Q1 to 2024 Q1, indicating a deterioration in profitability rather than improvement.
#
# [[ ## rationale ## ]]
# The analysis of key financial metrics shows a clear downward trend in profitability. Net income plummeted by over $1.3 billion, and both basic and diluted EPS decreased substantially. Increased interest and tax expenses further compressed earnings. These factors collectively suggest the company is not improving but instead experiencing challenges that reduce its profitability.
#
# [[ ## completed ## ]]
# {'teacher_question': "To determine if the company is improving its profitability, we need to analyze key financial metrics such as net income, earnings per share (EPS), and possibly other profitability ratios. Let's look at the data provided for two periods: 2023-Q1 and 2024-Q1.\n\n### Key Metrics:\n1. **Net Income**:\n   - 2023-Q1: $2,539 million\n   - 2024-Q1: $1,144 million\n\n2. **Net Income Attributable to Common Stockholders**:\n   - 2023-Q1: $2,513 million\n   - 2024-Q1: $1,129 million\n\n3. **Basic EPS**:\n   - 2023-Q1: $0.8 per share\n   - 2024-Q1: $0.37 per share\n\n4. **Diluted EPS**:\n   - 2023-Q1: $0.73 per share\n   - 2024-Q1: $0.34 per share\n\n5. **Basic Shares Outstanding**:\n   - 2023-Q1: ~3,166 million shares\n   - 2024-Q1: ~3,186 million shares\n\n### Analysis:\n- **Net Income Decline**: The net income decreased significantly from $2.54 billion in Q1 2023 to $1.14 billion in Q1 2024. This is a substantial drop of approximately 54%, which could indicate deteriorating profitability.\n- **EPS Reduction**: Both basic and diluted EPS declined sharply. Basic EPS fell from $0.8 to $0.37, and diluted EPS dropped from $0.73 to $0.34. This suggests that earnings per share are not only lower but also less diluted (i.e., fewer shares outstanding).\n- **Shares Outstanding**: There was a slight increase in basic shares outstanding from ~3.166 billion to ~3.186 billion, which might be due to stock issuance or other corporate actions. However, the decrease in EPS despite more shares indicates that earnings per share are being diluted further.\n\n### Conclusion:\nThe company’s profitability appears to have declined significantly between Q1 2023 and Q1 2024. The sharp drop in net income and EPS, combined with a slight increase in shares outstanding, suggests either reduced profitability per share or increased dilution (or both). Further analysis would be needed to understand the specific reasons behind these changes, such as revenue trends, cost structures, tax impacts, or corporate actions affecting shares.",
#  'critique': 'The question provided is not entirely Socratic because it lacks a direct inquiry that encourages critical thinking or exploration of underlying concepts. Instead, it presents a series of financial metrics and asks for an analysis of their implications on profitability. While the structure includes data and some preliminary observations, a more Socratic approach would involve asking questions like: "What factors could explain the decline in net income?" or "How does the change in EPS relate to changes in shares outstanding?" These types of questions prompt deeper reflection and reasoning rather than just summarizing provided information.',
#  'final_question': 'Is the company improving its profitability?',
#  'signal': "To determine if the company is improving its profitability, we need to analyze key financial metrics such as net income, earnings per share (EPS), and changes in expenses over time. Here's a step-by-step breakdown:\n\n1. **Net Income Comparison**: Compare net income from 2023 Q1 to 2024 Q1.\n   - 2023 Q1 Net Income: $2,539 million\n   - 2024 Q1 Net Income: $1,144 million\n   - **Change**: A decrease of $1,395 million (from +$2.5B to -$1.14B). This is a significant decline, indicating potential profitability issues.\n\n2. **Earnings Per Share (EPS)**:\n   - Basic EPS 2023 Q1: $0.80\n   - Diluted EPS 2023 Q1: $0.73\n   - Basic EPS 2024 Q1: $0.37\n   - Diluted EPS 2024 Q1: $0.34\n   - **Basic EPS Change**: Decrease from $0.80 to $0.37 (−$0.43)\n   - **Diluted EPS Change**: Decrease from $0.73 to $0.34 (−$0.39)\n   - Both metrics show a decline, suggesting reduced profitability per share.\n\n3. **Expense Analysis**:\n   - Interest Expense 2023 Q1: -$29 million\n   - Interest Expense 2024 Q1: -$76 million\n   - Increase in interest expense by $47 million (from −$29M to −$76M), which could be a factor in lower net income.\n   - Provision for Income Taxes 2023 Q1: -$261 million\n   - Provision for Income Taxes 2024 Q1: -$409 million\n   - Increase in tax provisions by $148 million (from −$261M to −$409M), further reducing net income.\n\n4. **Net Income Attributable to Common Stockholders**:\n   - 2023 Q1: $2,513 million\n   - 2024 Q1: $1,129 million\n   - Decrease of $1,384 million (from +$2.5B to −$1.13B), reinforcing the profitability decline.\n\n**Conclusion**: The company’s net income and EPS have significantly declined from 2023 Q1 to 2024 Q1, indicating a deterioration in profitability rather than improvement.",
#  'rationale': 'The analysis of key financial metrics shows a clear downward trend in profitability. Net income plummeted by over $1.3 billion, and both basic and diluted EPS decreased substantially. Increased interest and tax expenses further compressed earnings. These factors collectively suggest the company is not improving but instead experiencing challenges that reduce its profitability.'}

# %%
teacher = TeacherQuestioner()
critic = CriticJudge()
student = MarginAnalyzer()

program = MarsAnalysisProgram(teacher, critic, student)

from dspy.teleprompt import Teleprompter

# Wrap your MarsAnalysisProgram with tracing enabled
tp = Teleprompter(program)

# Run your pipeline through the teleprompter
result = tp(context=prompt, base_question="Is the company improving its profitability?")

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 10
#       7 from dspy.teleprompt import Teleprompter
#       9 # Wrap your MarsAnalysisProgram with tracing enabled
# ---> 10 tp = Teleprompter(program)
#      12 # Run your pipeline through the teleprompter
#      13 result = tp(context=prompt, base_question="Is the company improving its profitability?")
#
# TypeError: Teleprompter.__init__() takes 1 positional argument but 2 were given

# %%
teacher = TeacherQuestioner()
critic = CriticJudge()
student = MarginAnalyzer()

program = MarsAnalysisProgram(teacher, critic, student)

results = program(
    context=prompt,
    base_question="Is the company improving its profitability?"
)

dspy.inspect_history()
# Out:
# [2025-03-25T10:23:37.612565]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): Relevant financial data
# 2. `question` (str): User's trading question
#
# Your output fields are:
# 1. `signal` (str): Bullish, Bearish, or Neutral
# 2. `rationale` (str): Explanation for the signal
#
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## signal ## ]]
# {signal}
#
# [[ ## rationale ## ]]
# {rationale}
#
# [[ ## completed ## ]]
#
# In adhering to this structure, your objective is:
#         Given the fields `context`, `question`, produce the fields `signal`, `rationale`.
#
#
# User message:
#
# [[ ## context ## ]]
# You are a financial analysis model. Below are the last 3 income statements from TSLA.
#
# Analyze the trend in revenue and operating income.
# Decide if profitability is improving or declining.
# Then provide a trading signal.
#
# Respond with:
# Signal: <Bullish/Bearish/Neutral>
# Rationale: <short explanation>
#
# Revenues: 2023-01-01_2023-09-30: 71606000000.0 | 2023-07-01_2023-09-30: 23350000000.0 | 2024-01-01_2024-09-30: 71983000000.0 | 2024-07-01_2024-09-30: 25182000000.0
# Total cost of revenues: 2023-01-01_2023-09-30: -58384000000.0 | 2023-07-01_2023-09-30: -19172000000.0 | 2024-01-01_2024-09-30: -58712000000.0 | 2024-07-01_2024-09-30: -20185000000.0
# Gross profit: 2023-01-01_2023-09-30: 13222000000.0 | 2023-07-01_2023-09-30: 4178000000.0 | 2024-01-01_2024-09-30: 13271000000.0 | 2024-07-01_2024-09-30: 4997000000.0
# Net income attributable to common stockholders: 2023-01-01_2023-03-31: 2513000000.0 | 2024-01-01_2024-03-31: 1129000000.0
# Basic (in dollars per share): 2023-01-01_2023-03-31: 0.8 | 2024-01-01_2024-03-31: 0.37
# Diluted (in dollars per share): 2023-01-01_2023-03-31: 0.73 | 2024-01-01_2024-03-31: 0.34
# Basic (in shares): 2023-01-01_2023-03-31: 3166000000.0 | 2024-01-01_2024-03-31: 3186000000.0
# Diluted (in shares): 2023-01-01_2023-03-31: 3468000000.0 | 2024-01-01_2024-03-31: 3484000000.0
#
# [[ ## question ## ]]
# Is the company improving its profitability?
#
# Respond with the corresponding output fields, starting with the field `[[ ## signal ## ]]`, then `[[ ## rationale ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## signal ## ]]
# To determine if the company is improving its profitability, we need to analyze key financial metrics such as net income, earnings per share (EPS), and changes in expenses over time. Here's a step-by-step breakdown:
#
# 1. **Net Income Comparison**: Compare net income from 2023 Q1 to 2024 Q1.
#    - 2023 Q1 Net Income: $2,539 million
#    - 2024 Q1 Net Income: $1,144 million
#    - **Change**: A decrease of $1,395 million (from +$2.5B to -$1.14B). This is a significant decline, indicating potential profitability issues.
#
# 2. **Earnings Per Share (EPS)**:
#    - Basic EPS 2023 Q1: $0.80
#    - Diluted EPS 2023 Q1: $0.73
#    - Basic EPS 2024 Q1: $0.37
#    - Diluted EPS 2024 Q1: $0.34
#    - **Basic EPS Change**: Decrease from $0.80 to $0.37 (−$0.43)
#    - **Diluted EPS Change**: Decrease from $0.73 to $0.34 (−$0.39)
#    - Both metrics show a decline, suggesting reduced profitability per share.
#
# 3. **Expense Analysis**:
#    - Interest Expense 2023 Q1: -$29 million
#    - Interest Expense 2024 Q1: -$76 million
#    - Increase in interest expense by $47 million (from −$29M to −$76M), which could be a factor in lower net income.
#    - Provision for Income Taxes 2023 Q1: -$261 million
#    - Provision for Income Taxes 2024 Q1: -$409 million
#    - Increase in tax provisions by $148 million (from −$261M to −$409M), further reducing net income.
#
# 4. **Net Income Attributable to Common Stockholders**:
#    - 2023 Q1: $2,513 million
#    - 2024 Q1: $1,129 million
#    - Decrease of $1,384 million (from +$2.5B to −$1.13B), reinforcing the profitability decline.
#
# **Conclusion**: The company’s net income and EPS have significantly declined from 2023 Q1 to 2024 Q1, indicating a deterioration in profitability rather than improvement.
#
# [[ ## rationale ## ]]
# The analysis of key financial metrics shows a clear downward trend in profitability. Net income plummeted by over $1.3 billion, and both basic and diluted EPS decreased substantially. Increased interest and tax expenses further compressed earnings. These factors collectively suggest the company is not improving but instead experiencing challenges that reduce its profitability.
#
# [[ ## completed ## ]]

# %%
import dspy
teacher = TeacherQuestioner()
critic = CriticJudge()
student = MarginAnalyzer()

# Step 1: Teacher generates Socratic question
teacher_out = teacher(prompt=prompt)

# Step 2: Critic evaluates the question
critic_out = critic(question=teacher_out.question)

# Step 3: If the question is valid, pass it to the student
if "yes" in critic_out.critique.lower():
    student_out = student(context=prompt, question="Is profitability improving?", teacher_question=teacher_out.question)
else:
    student_out = student(context=prompt, question="Is profitability improving?")

print("📚 Teacher Question:", teacher_out.question)
print("🧐 Critique:", critic_out.critique)
print("📈 Signal:", student_out.signal)
print("🧠 Rationale:", student_out.rationale)

print(student_out)  # will show all fields in the Prediction

print(student_out.__dict__)
# Out:
# 📚 Teacher Question: Given the financial data provided, calculate the diluted earnings per share (EPS) for the fiscal year 2023. The data includes income statements and balance sheets for two periods: Q1 2023 (ending March 31) and Q4 2024 (ending December 31). The question specifically asks for the diluted EPS for 2023, which is derived from the net income attributable to common stockholders and the weighted average number of diluted shares outstanding during that year.
#
# To compute diluted EPS, the formula is:
# Diluted EPS = Net Income Attributable to Common Stockholders / Weighted Average Diluted Shares Outstanding
#
# The data shows two periods for 2023: Q1 (January–March) and the remaining quarters (April–December). However, since only Q1 2023 is provided with diluted EPS data, we need to infer if the entire year's diluted EPS can be calculated using this quarter's figures or if additional data from other quarters is required. The problem statement does not provide complete annual data for 2023 beyond Q1, so we must assume that only the Q1 2023 diluted EPS is available and that no further adjustments are needed unless specified otherwise.
#
# Looking at the provided data:
# - For Q1 2023 (ending March 31), Net Income Attributable to Common Stockholders is $2,513,000,000.
# - The diluted EPS for this quarter is listed as $0.73.
# - The weighted average diluted shares outstanding for Q1 2023 are 3,468,000,000.
#
# Using the formula:
# Diluted EPS = Net Income / Weighted Average Diluted Shares
# Plugging in the numbers:
# $0.73 = $2,513,000,000 / 3,468,000,000
#
# This confirms that the diluted EPS for Q1 2023 is correctly calculated as $0.73 using the provided figures. However, since the question asks for the diluted EPS for the entire fiscal year 2023, and only Q1 data is available, we must check if there's any indication in the data that the annual diluted EPS can be derived from this quarter alone or if additional quarters are needed.
#
# The problem statement does not provide net income or weighted average shares for other quarters of 2023 (Q2–Q4). Therefore, it is impossible to compute the full-year diluted EPS without assuming that only Q1's data applies or that there's a pattern across quarters. If we assume that the company's earnings and share count remained consistent throughout the year (which is a strong assumption), then multiplying the Q1 diluted EPS by four would give an approximate annual figure. However, this approach is speculative and not based on the provided data.
#
# Alternatively, if the question expects using only the available Q1 2023 data to represent the entire year, the answer would be $0.73 per share. But since EPS typically reflects a full fiscal year, and no other data points are given for 2023, this might not be accurate. However, given the constraints of the provided information, we must proceed with what's available.
#
# Another angle: The problem mentions "fiscal year 2023," which could refer to Q1 2023 as a standalone period or the entire year. If it's a typo and they meant Q1 2023, then the answer is $0.73. If it's the full year, but only Q1 data is provided, we can't compute it accurately without additional information.
#
# Given that the question explicitly asks for "diluted EPS for the fiscal year 2023," and no other annual figures are present in the dataset (only Q1), there might be an error in the problem setup or a misunderstanding of the data scope. However, based on the provided data, the only available diluted EPS is from Q1 2023. Therefore, unless instructed to extrapolate or assume consistency across quarters, which isn't supported by the data, the answer must rely solely on the given quarter's figures.
#
# Thus, the diluted EPS for fiscal year 2023 (Q1) is $0.73. If the question intended to ask about Q1 specifically, that's the value. Otherwise, without further data, it's impossible to compute a full-year figure accurately.
# 🧐 Critique: The question asks for the diluted earnings per share (EPS) for the fiscal year 2023. However, the provided data only includes information from Q1 2023 (ending March 31) and Q4 2024 (ending December 31). The problem explicitly states that only Q1 2023 has diluted EPS data available.
#
# To determine if the question is Socratic, we need to assess whether it encourages critical thinking or merely requires a straightforward calculation. Here’s the breakdown:
#
# 1. **Data Availability**: The user provided financial data for two periods: Q1 2023 and Q4 2024. Only Q1 2023 includes diluted EPS information. Since no other annual data is present, calculating the full-year diluted EPS for 2023 isn't possible without assumptions or extrapolation.
#
# 2. **Formula Application**: The formula for diluted EPS (Net Income / Weighted Average Diluted Shares) is correctly applied to Q1 2023 using the given figures ($2,513,000,000 net income and 3,468,000,000 weighted average shares), resulting in $0.73 EPS for that quarter.
#
# 3. **Critical Analysis**: The question’s phrasing ("fiscal year 2023") introduces ambiguity. If "fiscal year" refers to Q1 2023 alone (as the only available data), then the answer is straightforward. However, if it implies the entire calendar year (April–December 2023), additional data (e.g., net income and shares for Q2–Q4) are required. The absence of such data makes this a critical point.
#
# 4. **Assumptions**: If the problem assumes consistency across quarters (e.g., same EPS or share count throughout the year), the answer would be $0.73 multiplied by four, yielding an approximate annual figure. However, this is speculative and not supported by the provided data.
#
# 5. **Conclusion**: The question’s Socratic nature depends on whether it expects critical evaluation of data availability versus formula application. Since only Q1 2023 data is available, the answer must rely solely on that quarter’s figures unless instructed otherwise. This requires recognizing the limitation in data scope and either accepting the quarterly value or acknowledging the insufficiency for a full-year calculation.
#
# **Final Critique**: The question is partially Socratic because it challenges the respondent to analyze data limitations and make critical judgments about assumptions. However, if strictly following the provided data without extrapolation, the answer is derived from Q1 2023 alone.
# 📈 Signal: To determine if profitability is improving, we need to analyze key financial metrics such as net income, earnings per share (EPS), and return on equity (ROE) over time. Here's a step-by-step breakdown:
#
# 1. **Net Income**: Compare the net income for the two periods in question. If net income increased from 2023 Q1 to 2024 Q1, profitability is improving.
# 2. **Earnings Per Share (EPS)**: Calculate both basic and diluted EPS for each period. An increase in EPS indicates improved profitability per share.
# 3. **Return on Equity (ROE)**: Compute ROE using the formula ROE = Net Income / Shareholders' Equity. A higher ROE suggests better profitability relative to equity invested.
#
# **Data Analysis**:
# - For 2023 Q1: Net income is $2,539 million.
# - For 2024 Q1: Net income is $1,144 million.
# - Basic EPS for 2023 Q1: $0.8 per share; Diluted EPS: $0.73 per share.
# - Basic EPS for 2024 Q1: $0.37 per share; Diluted EPS: $0.34 per share.
#
# **Conclusion**: Net income decreased significantly from 2023 to 2024, and both basic and diluted EPS declined. This suggests a decline in profitability rather than improvement.
# 🧠 Rationale: Profitability is assessed by evaluating net income trends, earnings per share (EPS), and return on equity (ROE). Here’s the detailed reasoning:
#
# 1. **Net Income Decline**: The net income for 2023 Q1 was $2,539 million, while it dropped to $1,144 million in 2024 Q1. This represents a substantial decrease of approximately 55%, indicating reduced profitability.
#
# 2. **Earnings Per Share (EPS)**:
#    - Basic EPS decreased from $0.8 to $0.37.
#    - Diluted EPS fell from $0.73 to $0.34.
#    Both metrics show a decline, reflecting lower earnings per share available to shareholders.
#
# 3. **Return on Equity (ROE)**: ROE is calculated as Net Income divided by Shareholders' Equity. Assuming equity remained relatively stable:
#    - 2023 Q1 ROE = $2,539 million / Equity ≈ X%
#    - 2024 Q1 ROE = $1,144 million / Equity ≈ Y%
#    A lower ROE implies reduced profitability relative to equity invested.
#
# **Conclusion**: The data points consistently show a decline in profitability metrics. Therefore, profitability is not improving; instead, it has deteriorated significantly from 2023 to 2024.
# Prediction(
#     signal="To determine if profitability is improving, we need to analyze key financial metrics such as net income, earnings per share (EPS), and return on equity (ROE) over time. Here's a step-by-step breakdown:\n\n1. **Net Income**: Compare the net income for the two periods in question. If net income increased from 2023 Q1 to 2024 Q1, profitability is improving.\n2. **Earnings Per Share (EPS)**: Calculate both basic and diluted EPS for each period. An increase in EPS indicates improved profitability per share.\n3. **Return on Equity (ROE)**: Compute ROE using the formula ROE = Net Income / Shareholders' Equity. A higher ROE suggests better profitability relative to equity invested.\n\n**Data Analysis**:\n- For 2023 Q1: Net income is $2,539 million.\n- For 2024 Q1: Net income is $1,144 million.\n- Basic EPS for 2023 Q1: $0.8 per share; Diluted EPS: $0.73 per share.\n- Basic EPS for 2024 Q1: $0.37 per share; Diluted EPS: $0.34 per share.\n\n**Conclusion**: Net income decreased significantly from 2023 to 2024, and both basic and diluted EPS declined. This suggests a decline in profitability rather than improvement.",
#     rationale="Profitability is assessed by evaluating net income trends, earnings per share (EPS), and return on equity (ROE). Here’s the detailed reasoning:\n\n1. **Net Income Decline**: The net income for 2023 Q1 was $2,539 million, while it dropped to $1,144 million in 2024 Q1. This represents a substantial decrease of approximately 55%, indicating reduced profitability.\n\n2. **Earnings Per Share (EPS)**:\n   - Basic EPS decreased from $0.8 to $0.37.\n   - Diluted EPS fell from $0.73 to $0.34.\n   Both metrics show a decline, reflecting lower earnings per share available to shareholders.\n\n3. **Return on Equity (ROE)**: ROE is calculated as Net Income divided by Shareholders' Equity. Assuming equity remained relatively stable:\n   - 2023 Q1 ROE = $2,539 million / Equity ≈ X%\n   - 2024 Q1 ROE = $1,144 million / Equity ≈ Y%\n   A lower ROE implies reduced profitability relative to equity invested.\n\n**Conclusion**: The data points consistently show a decline in profitability metrics. Therefore, profitability is not improving; instead, it has deteriorated significantly from 2023 to 2024."
# )
# {'_store': {'signal': "To determine if profitability is improving, we need to analyze key financial metrics such as net income, earnings per share (EPS), and return on equity (ROE) over time. Here's a step-by-step breakdown:\n\n1. **Net Income**: Compare the net income for the two periods in question. If net income increased from 2023 Q1 to 2024 Q1, profitability is improving.\n2. **Earnings Per Share (EPS)**: Calculate both basic and diluted EPS for each period. An increase in EPS indicates improved profitability per share.\n3. **Return on Equity (ROE)**: Compute ROE using the formula ROE = Net Income / Shareholders' Equity. A higher ROE suggests better profitability relative to equity invested.\n\n**Data Analysis**:\n- For 2023 Q1: Net income is $2,539 million.\n- For 2024 Q1: Net income is $1,144 million.\n- Basic EPS for 2023 Q1: $0.8 per share; Diluted EPS: $0.73 per share.\n- Basic EPS for 2024 Q1: $0.37 per share; Diluted EPS: $0.34 per share.\n\n**Conclusion**: Net income decreased significantly from 2023 to 2024, and both basic and diluted EPS declined. This suggests a decline in profitability rather than improvement.", 'rationale': "Profitability is assessed by evaluating net income trends, earnings per share (EPS), and return on equity (ROE). Here’s the detailed reasoning:\n\n1. **Net Income Decline**: The net income for 2023 Q1 was $2,539 million, while it dropped to $1,144 million in 2024 Q1. This represents a substantial decrease of approximately 55%, indicating reduced profitability.\n\n2. **Earnings Per Share (EPS)**:\n   - Basic EPS decreased from $0.8 to $0.37.\n   - Diluted EPS fell from $0.73 to $0.34.\n   Both metrics show a decline, reflecting lower earnings per share available to shareholders.\n\n3. **Return on Equity (ROE)**: ROE is calculated as Net Income divided by Shareholders' Equity. Assuming equity remained relatively stable:\n   - 2023 Q1 ROE = $2,539 million / Equity ≈ X%\n   - 2024 Q1 ROE = $1,144 million / Equity ≈ Y%\n   A lower ROE implies reduced profitability relative to equity invested.\n\n**Conclusion**: The data points consistently show a decline in profitability metrics. Therefore, profitability is not improving; instead, it has deteriorated significantly from 2023 to 2024."}, '_completions': Completions(
#     signal=["To determine if profitability is improving, we need to analyze key financial metrics such as net income, earnings per share (EPS), and return on equity (ROE) over time. Here's a step-by-step breakdown:\n\n1. **Net Income**: Compare the net income for the two periods in question. If net income increased from 2023 Q1 to 2024 Q1, profitability is improving.\n2. **Earnings Per Share (EPS)**: Calculate both basic and diluted EPS for each period. An increase in EPS indicates improved profitability per share.\n3. **Return on Equity (ROE)**: Compute ROE using the formula ROE = Net Income / Shareholders' Equity. A higher ROE suggests better profitability relative to equity invested.\n\n**Data Analysis**:\n- For 2023 Q1: Net income is $2,539 million.\n- For 2024 Q1: Net income is $1,144 million.\n- Basic EPS for 2023 Q1: $0.8 per share; Diluted EPS: $0.73 per share.\n- Basic EPS for 2024 Q1: $0.37 per share; Diluted EPS: $0.34 per share.\n\n**Conclusion**: Net income decreased significantly from 2023 to 2024, and both basic and diluted EPS declined. This suggests a decline in profitability rather than improvement."],
#     rationale=["Profitability is assessed by evaluating net income trends, earnings per share (EPS), and return on equity (ROE). Here’s the detailed reasoning:\n\n1. **Net Income Decline**: The net income for 2023 Q1 was $2,539 million, while it dropped to $1,144 million in 2024 Q1. This represents a substantial decrease of approximately 55%, indicating reduced profitability.\n\n2. **Earnings Per Share (EPS)**:\n   - Basic EPS decreased from $0.8 to $0.37.\n   - Diluted EPS fell from $0.73 to $0.34.\n   Both metrics show a decline, reflecting lower earnings per share available to shareholders.\n\n3. **Return on Equity (ROE)**: ROE is calculated as Net Income divided by Shareholders' Equity. Assuming equity remained relatively stable:\n   - 2023 Q1 ROE = $2,539 million / Equity ≈ X%\n   - 2024 Q1 ROE = $1,144 million / Equity ≈ Y%\n   A lower ROE implies reduced profitability relative to equity invested.\n\n**Conclusion**: The data points consistently show a decline in profitability metrics. Therefore, profitability is not improving; instead, it has deteriorated significantly from 2023 to 2024."]
# )}
